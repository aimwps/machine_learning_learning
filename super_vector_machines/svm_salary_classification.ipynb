# %% [markdown]
# ## Adult Dataset Part 1: Cleaning and Preparation
#
# #### Objectives:
# 1. Preprocess the data and store the cleaned dataset as adult_clean.csv
# 2. Load clean dataset and test supervised/unsupervised models
#     - Goal: Determine best model to predict if new entry earns >50k or <50k with supervised learning
#     - Goal: Find insights and patterns in data using unspuervised learning
# 3. Apply k-folds cross validation
#     - Goal: Evaluate robustness of results across different models.
#     - Goal: Use and justify different error metrics
#
#
# #### Summary of dataset
#
# Datasource: https://archive.ics.uci.edu/ml/datasets/adult
#
# Feature descrptions copied below from the UCI website:
#
# - age: continuous.
# - workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - fnlwgt: Continuous. A weighting assigned from the sampling process.
# - education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - education-num: continuous.
# - marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - sex: Female, Male.
# - capital-gain: continuous.
# - capital-loss: continuous.
# - hours-per-week: continuous.
# - native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# - target: >50K, <=50K.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#original data does not come with headers. add headers based on the documentation descrption
headers = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 
           'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 
           'hours-per-week', 'native-country', 'target']

# %%
data = pd.read_csv('./data/adult.data', names = headers)
df = data.copy()
print(df.isna().sum())
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# target            0
# dtype: int64

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  target
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
df.sample(10)
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 19157   27            Private  145284        HS-grad              9
# 2705    40            Private  218903        HS-grad              9
# 2644    19            Private  196857        HS-grad              9
# 12487   34            Private  119153           11th              7
# 30368   26            Private  187248        HS-grad              9
# 15973   36            Private   66304   Some-college             10
# 22550   44            Private  171722        HS-grad              9
# 3522    45   Self-emp-not-inc  204205           10th              6
# 6992    31            Private  182237     Assoc-acdm             12
# 29645   22            Private  190903           11th              7
#
#             marital-status         occupation    relationship    race  \
# 19157   Married-civ-spouse    Farming-fishing         Husband   White
# 2705              Divorced       Tech-support       Unmarried   White
# 2644         Never-married      Other-service   Not-in-family   White
# 12487   Married-civ-spouse   Transport-moving         Husband   White
# 30368   Married-civ-spouse     Prof-specialty   Not-in-family   Black
# 15973   Married-civ-spouse   Transport-moving         Husband   White
# 22550            Separated      Other-service       Unmarried   White
# 3522    Married-civ-spouse       Craft-repair         Husband   White
# 6992    Married-civ-spouse              Sales         Husband   White
# 29645   Married-civ-spouse       Adm-clerical            Wife   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 19157     Male             0             0              40   United-States
# 2705    Female             0             0              40   United-States
# 2644    Female             0             0              40   United-States
# 12487     Male             0             0              50   United-States
# 30368     Male             0             0              40   United-States
# 15973     Male             0             0              45   United-States
# 22550   Female             0             0              39   United-States
# 3522      Male             0             0              65   United-States
# 6992      Male          4386             0              45   United-States
# 29645   Female             0             0              20   United-States
#
#        target
# 19157   <=50K
# 2705    <=50K
# 2644    <=50K
# 12487   <=50K
# 30368   <=50K
# 15973   <=50K
# 22550   <=50K
# 3522    <=50K
# 6992     >50K
# 29645   <=50K

# %% [markdown]
# On first look, it appears there are no missing values. **However the dataset descrption indicates that missing values have been flled with '?'.** Figure out what to do here :)

# %%
#code
print(df.iloc[11526])

df = df.replace("[?]", value=np.nan, regex=True)
print(df.iloc[11526])
print(df.isna().sum())
# Out:
# age                           18
# workclass                    NaN
# fnlwgt                     28357
# education           Some-college
# education-num                 10
# marital-status     Never-married
# occupation                   NaN
# relationship           Own-child
# race                       White
# sex                       Female
# capital-gain                   0
# capital-loss                   0
# hours-per-week                20
# native-country     United-States
# target                     <=50K
# Name: 11526, dtype: object
# age                           18
# workclass                    NaN
# fnlwgt                     28357
# education           Some-college
# education-num                 10
# marital-status     Never-married
# occupation                   NaN
# relationship           Own-child
# race                       White
# sex                       Female
# capital-gain                   0
# capital-loss                   0
# hours-per-week                20
# native-country     United-States
# target                     <=50K
# Name: 11526, dtype: object
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# target               0
# dtype: int64

# %% [markdown]
# Before deciding **how to deal with the missing values want to know how they influence the data**. For example, if workclass and occupation for example both have missing values (in the same tuple) it would be reasonable to drop the data.

# %%
occupation_nan = df[df['occupation'].isna()]
workclass_nan = df[df['workclass'].isna()]
print(f"shape of occupation_nan: {occupation_nan.shape}")
print(f"shape of workclass_nan: {workclass_nan.shape}")
nan_intersection_len = len(occupation_nan.index.intersection(workclass_nan.index))
print(f"workclass nan as part of occupation nan: {nan_intersection_len}")
# Out:
# shape of occupation_nan: (1843, 15)
# shape of workclass_nan: (1836, 15)
# workclass nan as part of occupation nan: 1836

# %% [markdown]
# **What % of the dataset do nans represent?** What is the **best approach** for dealing with the nan's?

# %%
total_rows =df.shape[0]
total_without_nans = df.dropna().shape[0]
total_nans = total_rows - total_without_nans
percent_nans = round(total_nans / total_rows, 2)
print(f"The percent of Nans is {percent_nans} or {total_nans}/{total_rows}")

print(df.info())
# Out:
# The percent of Nans is 0.07 or 2399/32561
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  31978 non-null  object
#  14  target          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None

# %%
#plot the categroical columns to see what we are dealing wit
# Add greater_than_50

nn_df = df.dropna()
nn_df.to_csv("data/adult_clean.csv")

# %%
#plot the numerical columns

# %% [markdown]
# #### Additional Steps:
# 1. Apply statistical tests to determine if dropping values changes the structure of the distribution in the workplace, occupation, and native-country categories i.e. t-test for differnce of modes.
# 2. Compare filling the workplace and occupation columns with mode values and applying same statistical tests.

# %%
def one_hot_encode_column(df, col_name):
    unique_splits = df[col_name].unique()
    df[[new_col for new_col in unique_splits]] = np.nan
    for new_col in unique_splits:
        print(new_col)
        df[new_col] = df[col_name].str.contains(new_col)
        df[new_col] = df[new_col].map({True: 1, False: 0})
        
    print(df.sample(10))
    return df

ehc_df = one_hot_encode_column(nn_df,'marital-status')
ehc_df = one_hot_encode_column(ehc_df,'education')
ehc_df = one_hot_encode_column(ehc_df,'workclass')
ehc_df = one_hot_encode_column(ehc_df,'relationship')
ehc_df = one_hot_encode_column(ehc_df,'occupation')
ehc_df = one_hot_encode_column(ehc_df,'sex')
ehc_df = one_hot_encode_column(ehc_df,'race')
ehc_df = one_hot_encode_column(ehc_df,'relationship')
ehc_df = one_hot_encode_column(ehc_df,'native-country')



ehc_df.to_csv("data/adult_clean_ehc.csv")
# Out:
# <ipython-input-26-43cc6d7c5bb3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[new_col for new_col in unique_splits]] = np.nan
# /home/aimwps/anaconda3/envs/AIMwpS/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-26-43cc6d7c5bb3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[col_name].str.contains(new_col)
# <ipython-input-26-43cc6d7c5bb3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[new_col].map({True: 1, False: 0})
# <ipython-input-26-43cc6d7c5bb3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[new_col for new_col in unique_splits]] = np.nan
# /home/aimwps/anaconda3/envs/AIMwpS/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Never-married
#  Married-civ-spouse
#  Divorced
#  Married-spouse-absent
#  Separated
#  Married-AF-spouse
#  Widowed
#        age     workclass  fnlwgt      education  education-num  \
# 8541    42     Local-gov  188291      Bachelors             13
# 22867   33   Federal-gov  331615      Doctorate             16
# 20330   37       Private  315291      Bachelors             13
# 1174    47       Private  183013        HS-grad              9
# 15922   23       Private  201680           12th              8
# 11126   39       Private  156897        HS-grad              9
# 3181    21       Private   57211        HS-grad              9
# 12273   23       Private  213719     Assoc-acdm             12
# 1445    50       Private   30447      Assoc-voc             11
# 6742    21       Private   83033   Some-college             10
#
#             marital-status         occupation     relationship    race  \
# 8541    Married-civ-spouse    Protective-serv          Husband   White
# 22867   Married-civ-spouse     Prof-specialty          Husband   White
# 20330        Never-married       Adm-clerical   Other-relative   Black
# 1174    Married-civ-spouse      Other-service          Husband   White
# 15922   Married-civ-spouse       Craft-repair          Husband   White
# 11126        Never-married       Craft-repair        Own-child   White
# 3181         Never-married       Craft-repair        Own-child   White
# 12273        Never-married              Sales        Own-child   Black
# 1445    Married-civ-spouse   Transport-moving          Husband   White
# 6742         Never-married      Other-service    Not-in-family   White
#
#            sex  ...   Outlying-US(Guam-USVI-etc)   Scotland   Trinadad&Tobago  \
# 8541      Male  ...                            0          0                 0
# 22867     Male  ...                            0          0                 0
# 20330   Female  ...                            0          0                 0
# 1174      Male  ...                            0          0                 0
# 15922     Male  ...                            0          0                 0
# 11126     Male  ...                            0          0                 0
# 3181      Male  ...                            0          0                 0
# 12273   Female  ...                            0          0                 0
# 1445      Male  ...                            0          0                 0
# 6742    Female  ...                            0          0                 0
#
#        Greece  Nicaragua   Vietnam   Hong   Ireland   Hungary  \
# 8541        0          0         0      0         0         0
# 22867       0          0         0      0         0         0
# 20330       0          0         0      0         0         0
# 1174        0          0         0      0         0         0
# 15922       0          0         0      0         0         0
# 11126       0          0         0      0         0         0
# 3181        0          0         0      0         0         0
# 12273       0          0         0      0         0         0
# 1445        0          0         0      0         0         0
# 6742        0          0         0      0         0         0
#
#         Holand-Netherlands
# 8541                     0
# 22867                    0
# 20330                    0
# 1174                     0
# 15922                    0
# 11126                    0
# 3181                     0
# 12273                    0
# 1445                     0
# 6742                     0
#
# [10 rows x 113 columns]
#  Bachelors
# <ipython-input-26-43cc6d7c5bb3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[col_name].str.contains(new_col)
# <ipython-input-26-43cc6d7c5bb3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[new_col].map({True: 1, False: 0})
#  HS-grad
#  11th
#  Masters
#  9th
#  Some-college
#  Assoc-acdm
#  7th-8th
#  Doctorate
#  Assoc-voc
#  Prof-school
#  5th-6th
#  10th
#  Preschool
#  12th
#  1st-4th
#        age   workclass  fnlwgt      education  education-num  \
# 30595   43     Private  342567      Bachelors             13
# 11347   20     Private  105585   Some-college             10
# 14216   34   State-gov  252529      Bachelors             13
# 15067   51   Local-gov   74784   Some-college             10
# 12277   24     Private   99970      Bachelors             13
# 6365    50   Local-gov  370733        HS-grad              9
# 18256   20     Private   58222   Some-college             10
# 30089   21     Private  170302        HS-grad              9
# 16866   48     Private   36228        HS-grad              9
# 24987   57   State-gov  283635   Some-college             10
#
#                marital-status          occupation     relationship    race  \
# 30595   Married-spouse-absent        Adm-clerical        Unmarried   White
# 11347           Never-married               Sales        Own-child   White
# 14216           Never-married      Prof-specialty    Not-in-family   White
# 15067                 Widowed        Adm-clerical    Not-in-family   White
# 12277           Never-married        Tech-support        Own-child   White
# 6365       Married-civ-spouse        Adm-clerical          Husband   Black
# 18256           Never-married   Handlers-cleaners        Own-child   White
# 30089           Never-married     Farming-fishing   Other-relative   White
# 16866                Divorced    Transport-moving    Not-in-family   White
# 24987                Divorced        Craft-repair    Not-in-family   White
#
#            sex  ...   Outlying-US(Guam-USVI-etc)   Scotland   Trinadad&Tobago  \
# 30595   Female  ...                            0          0                 0
# 11347     Male  ...                            0          0                 0
# 14216     Male  ...                            0          0                 0
# 15067   Female  ...                            0          0                 0
# 12277     Male  ...                            0          0                 0
# 6365      Male  ...                            0          0                 0
# 18256     Male  ...                            0          0                 0
# 30089     Male  ...                            0          0                 0
# 16866     Male  ...                            0          0                 0
# 24987   Female  ...                            0          0                 0
#
#        Greece  Nicaragua   Vietnam   Hong   Ireland   Hungary  \
# 30595       0          0         0      0         0         0
# 11347       0          0         0      0         0         0
# 14216       0          0         0      0         0         0
# 15067       0          0         0      0         0         0
# 12277       0          0         0      0         0         0
# 6365        0          0         0      0         0         0
# 18256       0          0         0      0         0         0
# 30089       0          0         0      0         0         0
# 16866       0          0         0      0         0         0
# 24987       0          0         0      0         0         0
#
#         Holand-Netherlands
# 30595                    0
# 11347                    0
# 14216                    0
# 15067                    0
# 12277                    0
# 6365                     0
# 18256                    0
# 30089                    0
# 16866                    0
# 24987                    0
#
# [10 rows x 113 columns]
#  State-gov
#  Self-emp-not-inc
#  Private
#  Federal-gov
#  Local-gov
#  Self-emp-inc
#  Without-pay
#        age   workclass  fnlwgt      education  education-num  \
# 25467   31     Private  209538           10th              6
# 5536    54   Local-gov  186884   Some-college             10
# 26872   28   Local-gov  100270      Bachelors             13
# 28386   33   Local-gov  246291      Bachelors             13
# 28213   27   Local-gov  116662        HS-grad              9
# 26018   23     Private  161478   Some-college             10
# 7633    37     Private  203828            9th              5
# 9682    27     Private  212041        HS-grad              9
# 1859    47   Local-gov  171095     Assoc-acdm             12
# 25723   17     Private  347322           10th              6
#
#             marital-status          occupation    relationship  \
# 25467   Married-civ-spouse   Machine-op-inspct         Husband
# 5536    Married-civ-spouse    Transport-moving         Husband
# 26872             Divorced      Prof-specialty   Not-in-family
# 28386        Never-married      Prof-specialty   Not-in-family
# 28213   Married-civ-spouse   Machine-op-inspct         Husband
# 26018        Never-married       Other-service       Own-child
# 7633    Married-civ-spouse        Craft-repair         Husband
# 9682         Never-married        Craft-repair   Not-in-family
# 1859    Married-civ-spouse        Adm-clerical            Wife
# 25723        Never-married               Sales       Own-child
#
#                       race      sex  ...   Outlying-US(Guam-USVI-etc)  \
# 25467                White     Male  ...                            0
# 5536                 Black     Male  ...                            0
# 26872                White     Male  ...                            0
# 28386                White   Female  ...                            0
# 28213                White     Male  ...                            0
# 26018   Asian-Pac-Islander   Female  ...                            0
# 7633                 White     Male  ...                            0
# 9682                 White     Male  ...                            0
# 1859                 White   Female  ...                            0
# 25723                White   Female  ...                            0
#
#         Scotland   Trinadad&Tobago  Greece  Nicaragua   Vietnam   Hong  \
# 25467          0                 0       0          0         0      0
# 5536           0                 0       0          0         0      0
# 26872          0                 0       0          0         0      0
# 28386          0                 0       0          0         0      0
# 28213          0                 0       0          0         0      0
# 26018          0                 0       0          0         0      0
# 7633           0                 0       0          0         0      0
# 9682           0                 0       0          0         0      0
# 1859           0                 0       0          0         0      0
# 25723          0                 0       0          0         0      0
#
#         Ireland   Hungary   Holand-Netherlands
# 25467         0         0                    0
# 5536          0         0                    0
# 26872         0         0                    0
# 28386         0         0                    0
# 28213         0         0                    0
# 26018         0         0                    0
# 7633          0         0                    0
# 9682          0         0                    0
# 1859          0         0                    0
# 25723         0         0                    0
#
# [10 rows x 113 columns]
#  Not-in-family
# <ipython-input-26-43cc6d7c5bb3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[new_col for new_col in unique_splits]] = np.nan
# /home/aimwps/anaconda3/envs/AIMwpS/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-26-43cc6d7c5bb3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[col_name].str.contains(new_col)
# <ipython-input-26-43cc6d7c5bb3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[new_col].map({True: 1, False: 0})
# <ipython-input-26-43cc6d7c5bb3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[new_col for new_col in unique_splits]] = np.nan
# /home/aimwps/anaconda3/envs/AIMwpS/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-26-43cc6d7c5bb3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[col_name].str.contains(new_col)
# <ipython-input-26-43cc6d7c5bb3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[new_col].map({True: 1, False: 0})
#  Husband
#  Wife
#  Own-child
#  Unmarried
#  Other-relative
#        age   workclass  fnlwgt      education  education-num  \
# 5149    28     Private  199600        HS-grad              9
# 20226   48     Private  159726        HS-grad              9
# 8013    45     Private  205424   Some-college             10
# 174     28   State-gov  149624      Bachelors             13
# 22908   30     Private  118056   Some-college             10
# 19243   40     Private  183404   Some-college             10
# 20238   21     Private   40767   Some-college             10
# 25232   23     Private   32950   Some-college             10
# 7226    27     Private  233421   Some-college             10
# 18882   43     Private  462180    Prof-school             15
#
#                marital-status          occupation    relationship    race  \
# 5149       Married-civ-spouse   Machine-op-inspct         Husband   Black
# 20226      Married-civ-spouse    Transport-moving         Husband   White
# 8013       Married-civ-spouse               Sales         Husband   White
# 174        Married-civ-spouse      Prof-specialty         Husband   White
# 22908   Married-spouse-absent     Exec-managerial       Unmarried   White
# 19243               Separated       Other-service       Unmarried   White
# 20238           Never-married   Handlers-cleaners   Not-in-family   White
# 25232           Never-married    Transport-moving   Not-in-family   White
# 7226            Never-married        Adm-clerical       Own-child   White
# 18882      Married-civ-spouse      Prof-specialty         Husband   White
#
#            sex  ...   Outlying-US(Guam-USVI-etc)   Scotland   Trinadad&Tobago  \
# 5149      Male  ...                            0          0                 0
# 20226     Male  ...                            0          0                 0
# 8013      Male  ...                            0          0                 0
# 174       Male  ...                            0          0                 0
# 22908   Female  ...                            0          0                 0
# 19243   Female  ...                            0          0                 0
# 20238     Male  ...                            0          0                 0
# 25232     Male  ...                            0          0                 0
# 7226      Male  ...                            0          0                 0
# 18882     Male  ...                            0          0                 0
#
#        Greece  Nicaragua   Vietnam   Hong   Ireland   Hungary  \
# 5149        0          0         0      0         0         0
# 20226       0          0         0      0         0         0
# 8013        0          0         0      0         0         0
# 174         0          0         0      0         0         0
# 22908       0          0         0      0         0         0
# 19243       0          0         0      0         0         0
# 20238       0          0         0      0         0         0
# 25232       0          0         0      0         0         0
# 7226        0          0         0      0         0         0
# 18882       0          0         0      0         0         0
#
#         Holand-Netherlands
# 5149                     0
# 20226                    0
# 8013                     0
# 174                      0
# 22908                    0
# 19243                    0
# 20238                    0
# 25232                    0
# 7226                     0
# 18882                    0
#
# [10 rows x 113 columns]
#  Adm-clerical
#  Exec-managerial
#  Handlers-cleaners
#  Prof-specialty
#  Other-service
# <ipython-input-26-43cc6d7c5bb3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[new_col for new_col in unique_splits]] = np.nan
# /home/aimwps/anaconda3/envs/AIMwpS/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-26-43cc6d7c5bb3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[col_name].str.contains(new_col)
# <ipython-input-26-43cc6d7c5bb3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[new_col].map({True: 1, False: 0})
#  Sales
#  Transport-moving
#  Farming-fishing
#  Machine-op-inspct
#  Tech-support
#  Craft-repair
#  Protective-serv
#  Armed-Forces
#  Priv-house-serv
#        age workclass  fnlwgt      education  education-num  \
# 24808   33   Private  238002            9th              5
# 15421   33   Private  186824      Assoc-voc             11
# 16870   53   Private  288353      Bachelors             13
# 4896    20   Private  194630        HS-grad              9
# 7271    28   Private  132686   Some-college             10
# 27405   18   Private  426836        5th-6th              3
# 8835    35   Private  180647   Some-college             10
# 15272   21   Private  372636        HS-grad              9
# 5115    49   Private  234320        7th-8th              4
# 23568   41   Private   40151   Some-college             10
#
#             marital-status          occupation     relationship    race  \
# 24808   Married-civ-spouse    Transport-moving   Other-relative   White
# 15421   Married-civ-spouse               Sales          Husband   White
# 16870   Married-civ-spouse     Exec-managerial          Husband   White
# 4896         Never-married               Sales    Not-in-family   White
# 7271    Married-civ-spouse     Exec-managerial          Husband   White
# 27405        Never-married   Handlers-cleaners   Other-relative   White
# 8835         Never-married      Prof-specialty    Not-in-family   Black
# 15272        Never-married               Sales        Own-child   Black
# 5115         Never-married      Prof-specialty   Other-relative   Black
# 23568             Divorced        Craft-repair    Not-in-family   White
#
#            sex  ...   Outlying-US(Guam-USVI-etc)   Scotland   Trinadad&Tobago  \
# 24808     Male  ...                            0          0                 0
# 15421     Male  ...                            0          0                 0
# 16870     Male  ...                            0          0                 0
# 4896      Male  ...                            0          0                 0
# 7271      Male  ...                            0          0                 0
# 27405     Male  ...                            0          0                 0
# 8835    Female  ...                            0          0                 0
# 15272     Male  ...                            0          0                 0
# 5115      Male  ...                            0          0                 0
# 23568     Male  ...                            0          0                 0
#
#        Greece  Nicaragua   Vietnam   Hong   Ireland   Hungary  \
# 24808       0          0         0      0         0         0
# 15421       0          0         0      0         0         0
# 16870       0          0         0      0         0         0
# 4896        0          0         0      0         0         0
# 7271        0          0         0      0         0         0
# 27405       0          0         0      0         0         0
# 8835        0          0         0      0         0         0
# 15272       0          0         0      0         0         0
# 5115        0          0         0      0         0         0
# 23568       0          0         0      0         0         0
#
#         Holand-Netherlands
# 24808                    0
# 15421                    0
# 16870                    0
# 4896                     0
# 7271                     0
# 27405                    0
# 8835                     0
# 15272                    0
# 5115                     0
# 23568                    0
#
# [10 rows x 113 columns]
#  Male
#  Female
# <ipython-input-26-43cc6d7c5bb3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[new_col for new_col in unique_splits]] = np.nan
# /home/aimwps/anaconda3/envs/AIMwpS/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-26-43cc6d7c5bb3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[col_name].str.contains(new_col)
# <ipython-input-26-43cc6d7c5bb3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[new_col].map({True: 1, False: 0})
# <ipython-input-26-43cc6d7c5bb3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[new_col for new_col in unique_splits]] = np.nan
# /home/aimwps/anaconda3/envs/AIMwpS/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-26-43cc6d7c5bb3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[col_name].str.contains(new_col)
# <ipython-input-26-43cc6d7c5bb3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[new_col].map({True: 1, False: 0})
# <ipython-input-26-43cc6d7c5bb3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[new_col for new_col in unique_splits]] = np.nan
# /home/aimwps/anaconda3/envs/AIMwpS/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#        age          workclass  fnlwgt      education  education-num  \
# 24506   21            Private  113106   Some-college             10
# 31485   48            Private   46677     Assoc-acdm             12
# 32560   52       Self-emp-inc  287927        HS-grad              9
# 17999   27            Private  137063      Bachelors             13
# 29825   25            Private  230292        HS-grad              9
# 12225   57            Private  201112     Assoc-acdm             12
# 19155   32            Private  440129   Some-college             10
# 6482    37   Self-emp-not-inc   48063      Bachelors             13
# 26469   19            Private  216804        7th-8th              4
# 13849   40            Private  299813           11th              7
#
#             marital-status          occupation    relationship    race  \
# 24506        Never-married       Other-service       Own-child   White
# 31485             Divorced     Exec-managerial       Unmarried   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
# 17999   Married-civ-spouse               Sales         Husband   White
# 29825   Married-civ-spouse        Craft-repair         Husband   White
# 12225             Divorced        Adm-clerical   Not-in-family   Black
# 19155   Married-civ-spouse   Handlers-cleaners         Husband   White
# 6482    Married-civ-spouse      Prof-specialty         Husband   White
# 26469        Never-married       Other-service       Own-child   White
# 13849        Never-married   Machine-op-inspct   Not-in-family   White
#
#            sex  ...   Outlying-US(Guam-USVI-etc)   Scotland   Trinadad&Tobago  \
# 24506   Female  ...                            0          0                 0
# 31485   Female  ...                            0          0                 0
# 32560   Female  ...                            0          0                 0
# 17999     Male  ...                            0          0                 0
# 29825     Male  ...                            0          0                 0
# 12225   Female  ...                            0          0                 0
# 19155     Male  ...                            0          0                 0
# 6482      Male  ...                            0          0                 0
# 26469     Male  ...                            0          0                 0
# 13849   Female  ...                            0          0                 0
#
#        Greece  Nicaragua   Vietnam   Hong   Ireland   Hungary  \
# 24506       0          0         0      0         0         0
# 31485       0          0         0      0         0         0
# 32560       0          0         0      0         0         0
# 17999       0          0         0      0         0         0
# 29825       0          0         0      0         0         0
# 12225       0          0         0      0         0         0
# 19155       0          0         0      0         0         0
# 6482        0          0         0      0         0         0
# 26469       0          0         0      0         0         0
# 13849       0          0         0      0         0         0
#
#         Holand-Netherlands
# 24506                    0
# 31485                    0
# 32560                    0
# 17999                    0
# 29825                    0
# 12225                    0
# 19155                    0
# 6482                     0
# 26469                    0
# 13849                    0
#
# [10 rows x 113 columns]
#  White
#  Black
#  Asian-Pac-Islander
#  Amer-Indian-Eskimo
#  Other
#        age   workclass  fnlwgt      education  education-num  \
# 5742    42     Private  196001        HS-grad              9
# 9769    57     Private  298507      Bachelors             13
# 9027    39     Private  258102   Some-college             10
# 1518    25     Private  212495      Bachelors             13
# 19488   32     Private  328199      Assoc-voc             11
# 7254    32     Private  199963           11th              7
# 13561   34     Private  206297      Bachelors             13
# 27076   45     Private  111979        HS-grad              9
# 26152   27     Private   32519   Some-college             10
# 5099    46   Local-gov  216414   Some-college             10
#
#             marital-status          occupation relationship  \
# 5742             Separated        Adm-clerical    Unmarried
# 9769    Married-civ-spouse      Prof-specialty      Husband
# 9027    Married-civ-spouse   Handlers-cleaners      Husband
# 1518         Never-married     Exec-managerial    Own-child
# 19488             Divorced     Exec-managerial    Unmarried
# 7254    Married-civ-spouse   Machine-op-inspct         Wife
# 13561   Married-civ-spouse     Exec-managerial      Husband
# 27076   Married-civ-spouse   Handlers-cleaners      Husband
# 26152   Married-civ-spouse               Sales      Husband
# 5099    Married-civ-spouse     Protective-serv      Husband
#
#                       race      sex  ...   Outlying-US(Guam-USVI-etc)  \
# 5742                 White   Female  ...                            0
# 9769                 White     Male  ...                            0
# 9027                 White     Male  ...                            0
# 1518                 White     Male  ...                            0
# 19488                White   Female  ...                            0
# 7254                 White   Female  ...                            0
# 13561                White     Male  ...                            0
# 27076                White     Male  ...                            0
# 26152   Asian-Pac-Islander     Male  ...                            0
# 5099                 White     Male  ...                            0
#
#         Scotland   Trinadad&Tobago  Greece  Nicaragua   Vietnam   Hong  \
# 5742           0                 0       0          0         0      0
# 9769           0                 0       0          0         0      0
# 9027           0                 0       0          0         0      0
# 1518           0                 0       0          0         0      0
# 19488          0                 0       0          0         0      0
# 7254           0                 0       0          0         0      0
# 13561          0                 0       0          0         0      0
# 27076          0                 0       0          0         0      0
# 26152          0                 0       0          0         0      0
# 5099           0                 0       0          0         0      0
#
#         Ireland   Hungary   Holand-Netherlands
# 5742          0         0                    0
# 9769          0         0                    0
# 9027          0         0                    0
# 1518          0         0                    0
# 19488         0         0                    0
# 7254          0         0                    0
# 13561         0         0                    0
# 27076         0         0                    0
# 26152         0         0                    0
# 5099          0         0                    0
#
# [10 rows x 113 columns]
#  Not-in-family
#  Husband
#  Wife
# <ipython-input-26-43cc6d7c5bb3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[col_name].str.contains(new_col)
# <ipython-input-26-43cc6d7c5bb3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[new_col].map({True: 1, False: 0})
# <ipython-input-26-43cc6d7c5bb3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[[new_col for new_col in unique_splits]] = np.nan
# /home/aimwps/anaconda3/envs/AIMwpS/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#  Own-child
#  Unmarried
#  Other-relative
#        age          workclass  fnlwgt      education  education-num  \
# 24101   33   Self-emp-not-inc  127894    Prof-school             15
# 31680   34            Private  102130        HS-grad              9
# 32508   45            Private  155093           10th              6
# 16875   53            Private  195638        HS-grad              9
# 17789   42   Self-emp-not-inc  201908    Prof-school             15
# 24301   48            Private   39530        HS-grad              9
# 24338   48            Private  174533        HS-grad              9
# 21042   27            Private  192936      Bachelors             13
# 10687   33            Private  112383   Some-college             10
# 13791   52   Self-emp-not-inc  217210        HS-grad              9
#
#             marital-status          occupation     relationship    race  \
# 24101   Married-civ-spouse      Prof-specialty          Husband   White
# 31680   Married-civ-spouse               Sales          Husband   White
# 32508             Divorced       Other-service    Not-in-family   Black
# 16875             Divorced        Adm-clerical    Not-in-family   White
# 17789   Married-civ-spouse      Prof-specialty          Husband   White
# 24301             Divorced        Adm-clerical    Not-in-family   White
# 24338   Married-civ-spouse   Machine-op-inspct          Husband   White
# 21042        Never-married      Prof-specialty    Not-in-family   White
# 10687   Married-civ-spouse      Prof-specialty          Husband   White
# 13791              Widowed       Other-service   Other-relative   Black
#
#            sex  ...   Outlying-US(Guam-USVI-etc)   Scotland   Trinadad&Tobago  \
# 24101     Male  ...                            0          0                 0
# 31680     Male  ...                            0          0                 0
# 32508   Female  ...                            0          0                 0
# 16875   Female  ...                            0          0                 0
# 17789     Male  ...                            0          0                 0
# 24301   Female  ...                            0          0                 0
# 24338     Male  ...                            0          0                 0
# 21042   Female  ...                            0          0                 0
# 10687     Male  ...                            0          0                 0
# 13791   Female  ...                            0          0                 0
#
#        Greece  Nicaragua   Vietnam   Hong   Ireland   Hungary  \
# 24101       0          0         0      0         0         0
# 31680       0          0         0      0         0         0
# 32508       0          0         0      0         0         0
# 16875       0          0         0      0         0         0
# 17789       0          0         0      0         0         0
# 24301       0          0         0      0         0         0
# 24338       0          0         0      0         0         0
# 21042       0          0         0      0         0         0
# 10687       0          0         0      0         0         0
# 13791       0          0         0      0         0         0
#
#         Holand-Netherlands
# 24101                    0
# 31680                    0
# 32508                    0
# 16875                    0
# 17789                    0
# 24301                    0
# 24338                    0
# 21042                    0
# 10687                    0
# 13791                    0
#
# [10 rows x 113 columns]
#  United-States
#  Cuba
#  Jamaica
#  India
#  Mexico
#  Puerto-Rico
#  Honduras
#  England
#  Canada
#  Germany
#  Iran
#  Philippines
#  Poland
#  Columbia
# <ipython-input-26-43cc6d7c5bb3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[col_name].str.contains(new_col)
# <ipython-input-26-43cc6d7c5bb3>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_col] = df[new_col].map({True: 1, False: 0})
#  Cambodia
#  Thailand
#  Ecuador
#  Laos
#  Taiwan
#  Haiti
#  Portugal
#  Dominican-Republic
#  El-Salvador
#  France
#  Guatemala
#  Italy
#  China
#  South
#  Japan
#  Yugoslavia
#  Peru
#  Outlying-US(Guam-USVI-etc)
#  Scotland
#  Trinadad&Tobago
#  Greece
#  Nicaragua
#  Vietnam
#  Hong
#  Ireland
#  Hungary
#  Holand-Netherlands
# /home/aimwps/anaconda3/envs/AIMwpS/lib/python3.8/site-packages/pandas/core/strings/accessor.py:101: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#        age          workclass  fnlwgt      education  education-num  \
# 199     24   Self-emp-not-inc   32921        HS-grad              9
# 17067   23            Private  193586        HS-grad              9
# 32552   43            Private   84661      Assoc-voc             11
# 19025   47            Private  155659   Some-college             10
# 1517    59            Private  284834      Bachelors             13
# 5051    52            Private   99185        HS-grad              9
# 14656   38            Private  193815        Masters             14
# 29417   23            Private  208946      Bachelors             13
# 12168   38        Federal-gov  214542   Some-college             10
# 1496    32            Private   80058           11th              7
#
#             marital-status          occupation    relationship    race  \
# 199          Never-married               Sales   Not-in-family   White
# 17067   Married-civ-spouse        Adm-clerical            Wife   White
# 32552   Married-civ-spouse               Sales         Husband   White
# 19025   Married-civ-spouse        Craft-repair         Husband   White
# 1517    Married-civ-spouse        Adm-clerical            Wife   White
# 5051    Married-civ-spouse               Sales         Husband   White
# 14656   Married-civ-spouse     Exec-managerial         Husband   White
# 29417        Never-married               Sales       Own-child   White
# 12168             Divorced   Handlers-cleaners       Unmarried   Black
# 1496              Divorced               Sales   Not-in-family   White
#
#            sex  ...   Outlying-US(Guam-USVI-etc)   Scotland   Trinadad&Tobago  \
# 199       Male  ...                            0          0                 0
# 17067   Female  ...                            0          0                 0
# 32552     Male  ...                            0          0                 0
# 19025     Male  ...                            0          0                 0
# 1517    Female  ...                            0          0                 0
# 5051      Male  ...                            0          0                 0
# 14656     Male  ...                            0          0                 0
# 29417     Male  ...                            0          0                 0
# 12168   Female  ...                            0          0                 0
# 1496      Male  ...                            0          0                 0
#
#        Greece  Nicaragua   Vietnam   Hong   Ireland   Hungary  \
# 199         0          0         0      0         0         0
# 17067       0          0         0      0         0         0
# 32552       0          0         0      0         0         0
# 19025       0          0         0      0         0         0
# 1517        0          0         0      0         0         0
# 5051        0          0         0      0         0         0
# 14656       0          0         0      0         0         0
# 29417       0          0         0      0         0         0
# 12168       0          0         0      0         0         0
# 1496        0          0         0      0         0         0
#
#         Holand-Netherlands
# 199                      0
# 17067                    0
# 32552                    0
# 19025                    0
# 1517                     0
# 5051                     0
# 14656                    0
# 29417                    0
# 12168                    0
# 1496                     0
#
# [10 rows x 113 columns]

# %%
#train / test... you know the drill
from sklearn.model_selection import train_test_split
from sklearn import svm

adult_df = pd.read_csv("data/adult_clean_ehc.csv")

Y = adult_df['target'].replace({" <=50K": 0, " >50K": 1})
print(Y)

X = adult_df.drop(['target','fnlwgt','education-num','marital-status','education','workclass','relationship','occupation','sex','race','relationship','native-country'], axis=1)

x_train, x_test, y_train, y_test = train_test_split(X,Y, random_state=909)
svc = svm.SVC(random_state=909).fit(x_train, y_train)
predict = svc.predict(x_test)
test_score = svc.score(x_test, y_test)
print(test_score)

# %% [markdown]
# # Discussion of results
